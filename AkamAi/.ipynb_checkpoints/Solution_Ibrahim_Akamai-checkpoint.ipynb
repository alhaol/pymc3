# %% [markdown]
# ## Ibrahim AbuAlhaol, Ottawa, Canada, DEC 10, 2017
#
# * Q1: Using data in Bar.csv, How much faster does the treatment improves the dom time?
#     - <b>Methodology:</b> A/B t-statistic test or ANOVA test to prove statistica significance
#     - <b>Results: </b>  On average, the treatment improves the dom time by 1.78  (21.08 -19.30)
# * Q2: Using data in Foo.csv, How much faster is H2 over H1? What percent improvement does H2 offer?
#     - <b>Methodology:</b> A/B t-statistic test or ANOVA test to prove statistical significance
#     - <b>Results: </b> No real difference (i.e.,significance) and therfore we can not conclude which one is faster
# * Q3: Any other interesting things that jump out from the data?
#     - <b>Methodology:</b> Pearson Correlation, Anova testing, and principal component analysis (PCA).
#     - <b>Results: BAR.CSV data </b>
#          - 'host', 'queryString', 'browser', 'isp', 'page' are related with statistical significance with the dom time
#          - 'dom'  and 'f1','f2','f3' ....,'f9' are not correlated with each other
#          - 'device' is not correlated with the 'dom' time
#
#     - <b>Results: FOO.CSV data </b>
#          - 'loadTime' is correlated (relatively) with most of the numerical features except 'run_no' and 'requests' as shown below
#          - 'requests' is related to 'label' and 'location' with high F-statistics
#          -  Many of the numerical features explain most of the variance in the 'loadTime' which is very expected but we here show that by statistical analysis

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style("darkgrid")
import numpy as np
import statsmodels.formula.api as smf
from scipy import stats
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %% [markdown]
# ### Functions

# %%
    
def VioPlot(Col1,Col2,Title='',size=10):
    fig, ax = plt.subplots(figsize=(size, size))
    sns.violinplot(x=Col1, y=Col2, showmeans=True,scale="width", inner="quartile")
    plt.title(Title)
    plt.show()
   

    

def Hist_Plot(A,B, x_label='x',legends=['',''],size=10):
    xweights = 100 * np.ones_like(A) / len(A)
    yweights = 100 * np.ones_like(B) / len(B)
    fig, ax = plt.subplots(figsize=(size, size))
    ax.hist(A, weights=xweights, color='lightblue', alpha=0.9, bins=50)
    ax.hist(B, weights=yweights, color='salmon', alpha=0.3,bins=50)
    ax.legend(legends)
    ax.set(title='Histogram Comparison', ylabel='% of Dataset in Bin')
    ax.margins(0.05)
    ax.set_ylim(bottom=0)
    plt.xlabel(x_label)
    plt.show()
    
def plot_corr(df):
    f, ax = plt.subplots(figsize=(15, 12))
    corr = df.corr()
    sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, ax=ax)
    plt.show()

# %% [markdown]
# ### Importing the CSV files

# %%
BAR=pd.read_csv('data/bar.csv')
FOO=pd.read_csv('data/foo.csv')
DF_trtmt_dom=BAR[['trtmt','dom']]
DF_FOO=FOO[['label','loadTime','fullyLoaded']]

# %% [markdown]
# # Q1:
# # -------

# %%
BAR.head(3)
# Out:
#    Unnamed: 0    host    page    isp    browser    device trtmt        dom  \
# 0           1  host_4  page_1  isp_2  browser_1  device_1    On  43.846811
# 1           2  host_2  page_3  isp_4  browser_3  device_1    On  34.078843
# 2           3  host_1  page_1  isp_1  browser_1  device_1    On  10.423054
#
#   queryString        f1        f2        f3        f4        f5        f6  \
# 0         Off  0.205366  0.817999  0.533166  0.358433  0.069712  0.370256
# 1         Off  0.455522  0.793443  0.090781  0.609515  0.746002  0.511265
# 2          On  0.195735  0.491308  0.147366  0.797300  0.409352  0.857075
#
#          f7        f8        f9
# 0  0.248647  0.562306  0.387616
# 1  0.664359  0.240108  0.696536
# 2  0.198729  0.850010  0.658896

# %%
VioPlot(BAR['trtmt'], BAR['dom'],'violet Plot of the dom time',12)

# %%
A=DF_trtmt_dom[DF_trtmt_dom['trtmt']=='On']['dom'].tolist()
B=DF_trtmt_dom[DF_trtmt_dom['trtmt']=='Off']['dom'].tolist()
Hist_Plot(A,B,'dom time',['With Treatement', 'Without Treatment'],size=12)

# %%
DOM_TRM_ON_Mean=DF_trtmt_dom[DF_trtmt_dom['trtmt']=='On']['dom'].mean()
DOM_TRM_OFF_Mean=DF_trtmt_dom[DF_trtmt_dom['trtmt']=='Off']['dom'].mean()
print ('\nThe average dom time with treatement = {}'.format(DOM_TRM_ON_Mean) )
print ('The average dom time without treatement = {} \n'.format(DOM_TRM_OFF_Mean) )
# Out:
# The average dom time with treatement = 19.30002315993797
# The average dom time without treatement = 21.080772215776854

# %% [markdown]
# * The difference in the dom time aveage does NOT prove the relationship between the treatment and the dom time.
# * We now run two tests : (1) A/B t-statistic test, and (2) ANOVA test
#
# >(1) The t-statistic (A/B test) is a measure of the difference between the two sets expressed in units of standard error. To have a real difference ("statistically significant" we need to see very low p-value and a high absolute value of the t-statistic .
#
#
# >(2) Anova F-statistic test to identify if the treatment (categorical predictor variable) associated or
#   related with the dom time (quantitative target variable)? to prove the relationship we look for high F-statistic and very low Prob (F-statistic) values.

# %% [markdown]
# #### (1) A/B t-statistic test

# %%
A=DF_trtmt_dom[DF_trtmt_dom['trtmt']=='On']['dom'].tolist()
B=DF_trtmt_dom[DF_trtmt_dom['trtmt']=='Off']['dom'].tolist()
stats.ttest_ind(A, B)
# Out:
# Ttest_indResult(statistic=-16.498032027469961, pvalue=7.063553955755318e-61)

# %% [markdown]
# - Hight absolute t-statistic =16.49  and low p-value=7e-61

# %% [markdown]
# #### (2) Anova F-statistic test

# %%
model = smf.ols(formula='dom ~ trtmt', data=BAR)
results = model.fit()
FValue=results.fvalue
FProp=results.f_pvalue 
R_sqr=results.rsquared
print ('\nF-statistic = {}'.format(FValue))
print ('Prob (F-statistic) = {}'.format(FProp))
#print (results.summary())
# Out:
# F-statistic = 272.1850607794322
# Prob (F-statistic) = 7.063553955518299e-61

# %% [markdown]
# - Hight F-statistic = 272.18  and low p-value=7e-61

# %% [markdown]
# * Given that the absolute t-statistics is high with very low p-value in the A/B test and/or the F-statistic is very large and the Prob (F-statistic) is very small in ANOVA test, then, we can say that the change in dom time is related to the treatement but with
#
# > On average, the treatment improves the dom time by 1.78  (21.08 -19.30)

# %% [markdown]
# * ------------------------------------------------------------------------------------------

# %% [markdown]
# # Q2:
# # -------

# %%
FOO.head(3)
# Out:
#          testId label             location  completed_time_stamp  \
# 0  171108_EG_BX    h1  WPTServer100:Chrome            1510215941
# 1  171108_60_6B    h1  WPTServer102:Chrome            1510172803
# 2  171108_60_6B    h1  WPTServer102:Chrome            1510172803
#
#         completed_time  run_no  loadTime  fullyLoaded  bytesIn  bytesInDoc  \
# 0  2017-11-09_03-25-41       1     15902        15902   634911           0
# 1  2017-11-08_15-26-43       8     45054        46018   929154      927960
# 2  2017-11-08_15-26-43      18     25006        25094   963762      962612
#
#    requests  requestsDoc  TTFB  firstPaint  render  SpeedIndex  docTime  \
# 0        86            0  7497           0   15800       15885        0
# 1        97           95  1511       43801   43800       44497    45054
# 2        98           97  1010        2680    2700       11964    25006
#
#    ttfb_first_req  ssl_first_req  dns_first_req
# 0            7260            104              0
# 1            1284            111              0
# 2             766            119              0

# %%
Diff=DF_FOO.apply(lambda row: row[2]-row[1],axis=1)

# %%
VioPlot(DF_FOO['label'], DF_FOO['loadTime'],'violet Plot of the loadTime',12)

# %%
A=DF_FOO[DF_FOO['label']=='h1']['loadTime'].tolist()
B=DF_FOO[DF_FOO['label']=='h2']['loadTime'].tolist()
Hist_Plot(A,B,'loadTime',legends=['h1','h2'],size=12)

# %%
print ('\nThe average loadTime in h1 = {}'.format(np.mean(A)))
print ('The average dom loadTime in h2 = {} \n'.format(np.mean(B)) )
# Out:
# The average loadTime in h1 = 5964.520833333333
# The average dom loadTime in h2 = 6302.229166666667

# %% [markdown]
# * The difference in the loadTime aveage does NOT prove the relationship with label (h1 or h2)
# * We now run two tests : (1) A/B t-statistic test, and (2) ANOVA test
#
# >(1) The t-statistic (A/B test) .
#
#
# >(2) Anova F-statistic test

# %% [markdown]
# #### (1) A/B t-statistic test

# %%
stats.ttest_ind(A, B)
# Out:
# Ttest_indResult(statistic=-0.8736228043200106, pvalue=0.3825426361512243)

# %% [markdown]
# - Low absolute t-statistic = 0.873  and high p-value=0.38

# %% [markdown]
# #### (2) Anova F-statistic test

# %%
model = smf.ols(formula='loadTime ~ label', data=DF_FOO)
results = model.fit()
FValue=results.fvalue
FProp=results.f_pvalue 
R_sqr=results.rsquared
print ('\nF-statistic = {}'.format(FValue))
print ('Prob (F-statistic) = {}'.format(FProp))
#print (results.summary())
# Out:
# F-statistic = 0.7632168042276727
# Prob (F-statistic) = 0.3825426361510831

# %% [markdown]
# - Low F-statistic = 0.763 and High p-value = 0.382

# %% [markdown]
# * Given that the absolute t-statistics is low with very high p-value in the A/B test and/or the F-statistic is very low and the Prob (F-statistic) is very high in ANOVA test, then
#
#
# > No real difference (i.e., no statistical significance) and therfore we can not conclude which one is faster

# %% [markdown]
# # Q3:
# # -------

# %%
# Pearson Correlation

# %%
BAR=BAR[BAR.columns[1:]]
plot_corr(BAR)

# %%
BAR.corr()
# Out:
#           dom        f1        f2        f3        f4        f5        f6  \
# dom  1.000000 -0.004268 -0.009095  0.006870 -0.002335 -0.007035  0.000647
# f1  -0.004268  1.000000  0.001720 -0.004882 -0.005273 -0.001245  0.005581
# f2  -0.009095  0.001720  1.000000  0.001018 -0.001906 -0.005101  0.002350
# f3   0.006870 -0.004882  0.001018  1.000000 -0.002628 -0.004128 -0.012043
# f4  -0.002335 -0.005273 -0.001906 -0.002628  1.000000  0.000314 -0.002523
# f5  -0.007035 -0.001245 -0.005101 -0.004128  0.000314  1.000000 -0.008828
# f6   0.000647  0.005581  0.002350 -0.012043 -0.002523 -0.008828  1.000000
# f7   0.001945  0.002995  0.003597  0.010262 -0.008377 -0.009184 -0.001538
# f8   0.007762  0.005796  0.000874 -0.007281  0.002205  0.005812  0.003601
# f9  -0.000939  0.004510  0.003751  0.000404  0.001908 -0.000252  0.001398
#
#            f7        f8        f9
# dom  0.001945  0.007762 -0.000939
# f1   0.002995  0.005796  0.004510
# f2   0.003597  0.000874  0.003751
# f3   0.010262 -0.007281  0.000404
# f4  -0.008377  0.002205  0.001908
# f5  -0.009184  0.005812 -0.000252
# f6  -0.001538  0.003601  0.001398
# f7   1.000000  0.006083 -0.000910
# f8   0.006083  1.000000 -0.009387
# f9  -0.000910 -0.009387  1.000000

# %% [markdown]
# From the correlation matrix above
# > dom time and f1,f2,f3 ....,f9 are not correlated with each other

# %%
def plot_feature_class_mean(DF,features,label,En_plot=False):
    ANOVA_DF=pd.DataFrame(index=list(features),columns=['F_value','F_prop','R_sqr','R_sqr_ajd'])
    for feature in features:
        if En_plot==True:
            sns.boxplot(x=DF[label], y=DF[feature], showmeans=True)
            plt.grid()
            plt.show()
        #ANOVA F Test
        model = smf.ols(formula=str(feature)+' ~ '+str(label), data=DF)
        results = model.fit()
        F_Prop=results.f_pvalue
        F_value=results.fvalue
        R_sqr=results.rsquared
        R_adj_sqr=results.rsquared_adj
        ANOVA_DF.loc[feature]=[F_value,F_Prop,R_sqr,R_adj_sqr]
    return  ANOVA_DF

# %%
BAR.head(3)
# Out:
#      host    page    isp    browser    device trtmt        dom queryString  \
# 0  host_4  page_1  isp_2  browser_1  device_1    On  43.846811         Off
# 1  host_2  page_3  isp_4  browser_3  device_1    On  34.078843         Off
# 2  host_1  page_1  isp_1  browser_1  device_1    On  10.423054          On
#
#          f1        f2        f3        f4        f5        f6        f7  \
# 0  0.205366  0.817999  0.533166  0.358433  0.069712  0.370256  0.248647
# 1  0.455522  0.793443  0.090781  0.609515  0.746002  0.511265  0.664359
# 2  0.195735  0.491308  0.147366  0.797300  0.409352  0.857075  0.198729
#
#          f8        f9
# 0  0.562306  0.387616
# 1  0.240108  0.696536
# 2  0.850010  0.658896

# %% [markdown]
# # Applying ANOVA test for all categorical variables
# - 'host',
# - 'page',
# - 'isp',
# - 'browser',
# - 'device',
# - 'queryString'

# %%
Features=BAR.columns[[6,8,9,10,11,12,13,14,15,16]]
Labels=['host','page','isp','browser','device','queryString']
for lab in Labels:
    ANOVA_DF=plot_feature_class_mean(BAR,Features,lab, False)
    print('\n=====================ANOVA with {}====================='.format (lab))
    print(ANOVA_DF)

print ("=======================================================")
# Out:
# =====================ANOVA with host=====================
#       F_value    F_prop        R_sqr    R_sqr_ajd
# dom   1575.54         0     0.442476     0.442195
# f1   0.513991  0.934862  0.000258844 -0.000244753
# f2   0.752182  0.732283  0.000378751 -0.000124786
# f3    1.47455  0.104828  0.000742219  0.000238866
# f4   0.491761  0.946328  0.000247652  -0.00025595
# f5   0.599168  0.878138  0.000301726 -0.000201849
# f6   0.831914  0.642484  0.000418882 -8.46341e-05
# f7   0.712825  0.774053   0.00035894 -0.000144606
# f8   0.927349  0.532364  0.000466913 -3.65791e-05
# f9   0.956264  0.499643  0.000481465 -2.20204e-05
#
# =====================ANOVA with page=====================
#       F_value        F_prop        R_sqr    R_sqr_ajd
# dom   52.9434  1.70713e-167     0.027661    0.0271386
# f1    1.91253     0.0151639    0.0010266  0.000489825
# f2    1.00188      0.450897   0.00053805  1.01173e-06
# f3   0.739241      0.755714  0.000397057 -0.000140058
# f4    1.02456      0.425937  0.000550219  1.31874e-05
# f5    1.03382      0.415918  0.000555193  1.81641e-05
# f6   0.965062      0.492634  0.000518286 -1.87633e-05
# f7   0.597877      0.888254  0.000321152 -0.000216003
# f8    0.88589      0.585738  0.000475787 -6.12851e-05
# f9    1.05307      0.395481  0.000565522  2.84981e-05
#
# =====================ANOVA with isp=====================
#       F_value    F_prop        R_sqr    R_sqr_ajd
# dom    885.16         0     0.211029     0.210791
# f1   0.415876  0.927494  0.000125652 -0.000176486
# f2   0.676559  0.730966  0.000204398 -9.77159e-05
# f3   0.420797  0.924841  0.000127139 -0.000174999
# f4   0.731726  0.680178  0.000221061  -8.1048e-05
# f5   0.558328  0.832113  0.000168685  -0.00013344
# f6   0.842557  0.576659  0.000254535 -4.75635e-05
# f7    1.52003   0.13422  0.000459106  0.000157069
# f8    1.23497  0.267975   0.00037304  7.09771e-05
# f9   0.618924   0.78202  0.000186989  -0.00011513
#
# =====================ANOVA with browser=====================
#       F_value     F_prop        R_sqr    R_sqr_ajd
# dom   184.162          0    0.0527158    0.0524295
# f1    1.94756  0.0411021   0.00058816  0.000286162
# f2   0.318913   0.969212  9.63584e-05 -0.000205788
# f3   0.570359   0.822528  0.000172319 -0.000129805
# f4   0.927005   0.499998   0.00028004 -2.20513e-05
# f5   0.966152    0.46588  0.000291862  -1.0225e-05
# f6   0.751419     0.6618  0.000227009  -7.5098e-05
# f7    1.01951   0.421257  0.000307976  5.89336e-06
# f8   0.492005   0.881038   0.00014865 -0.000153481
# f9   0.704243   0.705644   0.00021276 -8.93514e-05
#
# =====================ANOVA with device=====================
#       F_value     F_prop        R_sqr    R_sqr_ajd
# dom  0.949645   0.480135  0.000286877 -1.52118e-05
# f1    1.61295   0.105158  0.000487156  0.000185128
# f2   0.587654    0.80842  0.000177543 -0.000124579
# f3   0.461136   0.901236  0.000139325 -0.000162809
# f4   0.907642   0.517247  0.000274192 -2.79005e-05
# f5   0.976556      0.457  0.000295004 -7.08221e-06
# f6    1.96969  0.0385138  0.000594838  0.000292842
# f7    1.36697   0.196833  0.000412895  0.000110844
# f8   0.872486     0.5491  0.000263575 -3.85214e-05
# f9    0.45744   0.903534  0.000138208 -0.000163926
#
# =====================ANOVA with queryString=====================
#         F_value       F_prop        R_sqr    R_sqr_ajd
# dom     98.5709  3.40737e-23   0.00329772   0.00326427
# f1    0.0104104     0.918732  3.49437e-07 -3.32166e-05
# f2     0.431699     0.511161  1.44902e-05 -1.90753e-05
# f3   0.00625941     0.936941  2.10104e-07 -3.33559e-05
# f4      4.35981     0.036805   0.00014632  0.000112759
# f5      1.12617     0.288602  3.77998e-05    4.235e-06
# f6    0.0573981     0.810658  1.92662e-06 -3.16394e-05
# f7      1.34058     0.246941  4.49959e-05  1.14313e-05
# f8     0.145109     0.703257  4.87071e-06 -2.86952e-05
# f9     0.521397     0.470252  1.75009e-05 -1.60645e-05
# =======================================================

# %% [markdown]
# ### From the above results on BAR.csv data:
# * host, queryString, browser, isp, page are related with statistical significance with the dom time
# * device is not correlated with the dom time

# %% [markdown]
#  -------------------- ----------------------------------------------------------------------------------------------------

# %%
FOO.head(3)
# Out:
#          testId label             location  completed_time_stamp  \
# 0  171108_EG_BX    h1  WPTServer100:Chrome            1510215941
# 1  171108_60_6B    h1  WPTServer102:Chrome            1510172803
# 2  171108_60_6B    h1  WPTServer102:Chrome            1510172803
#
#         completed_time  run_no  loadTime  fullyLoaded  bytesIn  bytesInDoc  \
# 0  2017-11-09_03-25-41       1     15902        15902   634911           0
# 1  2017-11-08_15-26-43       8     45054        46018   929154      927960
# 2  2017-11-08_15-26-43      18     25006        25094   963762      962612
#
#    requests  requestsDoc  TTFB  firstPaint  render  SpeedIndex  docTime  \
# 0        86            0  7497           0   15800       15885        0
# 1        97           95  1511       43801   43800       44497    45054
# 2        98           97  1010        2680    2700       11964    25006
#
#    ttfb_first_req  ssl_first_req  dns_first_req
# 0            7260            104              0
# 1            1284            111              0
# 2             766            119              0

# %% [markdown]
# ## Pearson correlation

# %%
plot_corr(FOO[FOO.columns[0:-2]])

# %%
FOO[FOO.columns[0:-2]].corr()
# Out:
#                       completed_time_stamp    run_no  loadTime  fullyLoaded  \
# completed_time_stamp              1.000000  0.000000 -0.240292    -0.159038
# run_no                            0.000000  1.000000 -0.035689    -0.058041
# loadTime                         -0.240292 -0.035689  1.000000     0.881473
# fullyLoaded                      -0.159038 -0.058041  0.881473     1.000000
# bytesIn                           0.007876 -0.048068  0.369946     0.604159
# bytesInDoc                       -0.115974 -0.020020  0.503299     0.504099
# requests                         -0.024836 -0.025821  0.058097     0.111647
# requestsDoc                      -0.098903 -0.020400  0.040161     0.008707
# TTFB                              0.045251 -0.051665  0.197234     0.170064
# firstPaint                       -0.138790 -0.040207  0.668293     0.573242
# render                           -0.131219 -0.048601  0.671666     0.573612
# SpeedIndex                       -0.198930 -0.050843  0.896433     0.791800
# docTime                          -0.246716 -0.033875  0.995147     0.879433
# ttfb_first_req                    0.061173 -0.045520  0.176893     0.151765
#
#                        bytesIn  bytesInDoc  requests  requestsDoc      TTFB  \
# completed_time_stamp  0.007876   -0.115974 -0.024836    -0.098903  0.045251
# run_no               -0.048068   -0.020020 -0.025821    -0.020400 -0.051665
# loadTime              0.369946    0.503299  0.058097     0.040161  0.197234
# fullyLoaded           0.604159    0.504099  0.111647     0.008707  0.170064
# bytesIn               1.000000    0.775295  0.284910     0.102962  0.003180
# bytesInDoc            0.775295    1.000000  0.409192     0.355629 -0.018947
# requests              0.284910    0.409192  1.000000     0.675690 -0.109034
# requestsDoc           0.102962    0.355629  0.675690     1.000000 -0.129877
# TTFB                  0.003180   -0.018947 -0.109034    -0.129877  1.000000
# firstPaint            0.123573    0.186304 -0.005223     0.084457  0.354198
# render                0.112788    0.161425 -0.043265    -0.001533  0.382612
# SpeedIndex            0.209017    0.259374 -0.003971     0.028308  0.317905
# docTime               0.378366    0.526058  0.097730     0.123664  0.179630
# ttfb_first_req       -0.007088   -0.030090 -0.110680    -0.131912  0.995724
#
#                       firstPaint    render  SpeedIndex   docTime  \
# completed_time_stamp   -0.138790 -0.131219   -0.198930 -0.246716
# run_no                 -0.040207 -0.048601   -0.050843 -0.033875
# loadTime                0.668293  0.671666    0.896433  0.995147
# fullyLoaded             0.573242  0.573612    0.791800  0.879433
# bytesIn                 0.123573  0.112788    0.209017  0.378366
# bytesInDoc              0.186304  0.161425    0.259374  0.526058
# requests               -0.005223 -0.043265   -0.003971  0.097730
# requestsDoc             0.084457 -0.001533    0.028308  0.123664
# TTFB                    0.354198  0.382612    0.317905  0.179630
# firstPaint              1.000000  0.987407    0.894932  0.673685
# render                  0.987407  1.000000    0.903429  0.663515
# SpeedIndex              0.894932  0.903429    1.000000  0.890895
# docTime                 0.673685  0.663515    0.890895  1.000000
# ttfb_first_req          0.335440  0.364118    0.296652  0.159223
#
#                       ttfb_first_req
# completed_time_stamp        0.061173
# run_no                     -0.045520
# loadTime                    0.176893
# fullyLoaded                 0.151765
# bytesIn                    -0.007088
# bytesInDoc                 -0.030090
# requests                   -0.110680
# requestsDoc                -0.131912
# TTFB                        0.995724
# firstPaint                  0.335440
# render                      0.364118
# SpeedIndex                  0.296652
# docTime                     0.159223
# ttfb_first_req              1.000000

# %% [markdown]
# > ## 'loadTime' is correlated relatively with most of the features except 'run_no' and requests as shown above

# %% [markdown]
# # Applying ANOVA test for all categorical variables
#
# - 'label',
# - 'location',
# - 'run_no',
# - 'testId'

# %%
Features=FOO.columns[6:-1].tolist()
Labels=['label','location','run_no','testId']
for lab in Labels:
    ANOVA_DF=plot_feature_class_mean(FOO,Features,lab, False)
    print('\n=====================ANOVA with {}====================='.format (lab))
    print(ANOVA_DF)

print ("=======================================================")
# Out:
# =====================ANOVA with label=====================
#                   F_value        F_prop        R_sqr    R_sqr_ajd
# loadTime         0.763217      0.382543  0.000796043 -0.000246967
# fullyLoaded      0.669947      0.413273   0.00069883 -0.000344282
# bytesIn             6.866    0.00892416   0.00711601    0.0060796
# bytesInDoc        13.6598   0.000231518    0.0140582     0.013029
# requests          969.511  1.31985e-147     0.502986     0.502467
# requestsDoc       32.6587   1.46616e-08    0.0329666    0.0319572
# TTFB              2.96445     0.0854361   0.00308487   0.00204425
# firstPaint       0.788031      0.374919  0.000821904  -0.00022108
# render            1.11951      0.290291   0.00116723  0.000124604
# SpeedIndex      0.0165786      0.897576  1.73051e-05  -0.00102652
# docTime          0.793782      0.373183  0.000827897 -0.000215081
# ttfb_first_req    2.91333     0.0881745   0.00303183   0.00199116
# ssl_first_req     1.42078       0.23357   0.00148087  0.000438579
#
# =====================ANOVA with location=====================
#                  F_value       F_prop        R_sqr   R_sqr_ajd
# loadTime         1.91807     0.147455    0.0039925  0.00191098
# fullyLoaded      66.0943   1.2958e-27     0.121364    0.119528
# bytesIn          240.501  2.38967e-85     0.334494    0.333103
# bytesInDoc       3.57242     0.028463   0.00741055  0.00533617
# requests        0.206721     0.813283  0.000431832 -0.00165713
# requestsDoc      12.7628  3.38702e-06    0.0259796    0.023944
# TTFB             2.45664    0.0862631   0.00510782  0.00302863
# firstPaint       6.72372   0.00125965     0.013857    0.011796
# render           7.34037  0.000685996    0.0151086   0.0130503
# SpeedIndex       8.97531  0.000137461    0.0184118   0.0163604
# docTime          1.51441     0.220464   0.00315493  0.00107166
# ttfb_first_req   1.91103     0.148493    0.0039779  0.00189635
# ssl_first_req    1.83827     0.159653   0.00382704  0.00174517
#
# =====================ANOVA with run_no=====================
#                  F_value     F_prop        R_sqr    R_sqr_ajd
# loadTime         1.22175   0.269295   0.00127369  0.000231178
# fullyLoaded      3.23812  0.0722575    0.0033687   0.00232838
# bytesIn          2.21862   0.136684   0.00231054   0.00126911
# bytesInDoc      0.384109    0.53556  0.000400788 -0.000642635
# requests        0.639155   0.424215  0.000666732 -0.000376414
# requestsDoc     0.398833   0.527843  0.000416145 -0.000627262
# TTFB             2.56396   0.109654   0.00266923   0.00162817
# firstPaint       1.55118   0.213266   0.00161656   0.00057441
# render           2.26821   0.132382   0.00236206   0.00132069
# SpeedIndex       2.48289    0.11542   0.00258505    0.0015439
# docTime          1.10061   0.294397   0.00114754  0.000104899
# ttfb_first_req   1.98914   0.158756   0.00207204   0.00103036
# ssl_first_req    5.32367  0.0212501   0.00552635   0.00448828
#
# =====================ANOVA with testId=====================
#                 F_value        F_prop      R_sqr   R_sqr_ajd
# loadTime        7.00489   2.51987e-36   0.265245    0.227379
# fullyLoaded     7.84751   9.48955e-42   0.287963    0.251269
# bytesIn         15.1835   7.26011e-85   0.438984    0.410072
# bytesInDoc      2.81153   3.35032e-09   0.126555   0.0815424
# requests        24.2409  1.22043e-128   0.555409    0.532497
# requestsDoc     2.48863   2.53193e-07   0.113673    0.067996
# TTFB            1.91521   0.000275214   0.089834   0.0429285
# firstPaint      5.00365   3.29329e-23   0.205001    0.164031
# render           4.9191   1.18559e-22   0.202238    0.161125
# SpeedIndex      6.30114    9.7103e-32   0.245129    0.206227
# docTime         7.00074   2.68086e-36   0.265129    0.227258
# ttfb_first_req  1.93308   0.000225357  0.0905963   0.0437301
# ssl_first_req   0.93219      0.604227  0.0458384 -0.00333441
# =======================================================

# %% [markdown]
# > ## 'requests' is related to 'label' and 'location' with high F-statistics

# %%
DF_New=FOO[FOO.columns[6:-2]]
DF_New.head(10)
# Out:
#    loadTime  fullyLoaded  bytesIn  bytesInDoc  requests  requestsDoc  TTFB  \
# 0     15902        15902   634911           0        86            0  7497
# 1     45054        46018   929154      927960        97           95  1511
# 2     25006        25094   963762      962612        98           97  1010
# 3     24283        24352  1006265     1005115        99           98  1432
# 4     23829        23904   882269      881119        99           98  1005
# 5     44898        45030   950278      949128        99           98  1018
# 6     45051        45165  1090232     1089082        99           98   984
# 7      6081         6602  1041090     1039896        99           97  1029
# 8      4286         4999   951761      950567        99           97  1141
# 9     24662        24740   911578      910428        99           98  1789
#
#    firstPaint  render  SpeedIndex  docTime  ttfb_first_req
# 0           0   15800       15885        0            7260
# 1       43801   43800       44497    45054            1284
# 2        2680    2700       11964    25006             766
# 3       22778   22700       23424    24283            1216
# 4       22335   22300       23013    23829             767
# 5        2655    2600       20966    44898             766
# 6        2614    2600       21029    45051             757
# 7        4469    4500        5185     6081             799
# 8        2750    2800        3501     4286             942
# 9       23110   23100       23867    24662             755

# %%
X = DF_New.iloc[:,1:]
y = DF_New.loadTime
pca = PCA()
X_reduced = pca.fit_transform(scale(X))
PERC=list(np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100))
FEAT=list(X.columns)
DF_PCA=pd.DataFrame({'Feature':FEAT,'Explained_Variance':PERC})
DF_PCA [['Feature','Explained_Variance']]
# Out:
#            Feature  Explained_Variance
# 0      fullyLoaded               43.08
# 1          bytesIn               66.10
# 2       bytesInDoc               79.37
# 3         requests               90.61
# 4      requestsDoc               94.34
# 5             TTFB               97.53
# 6       firstPaint               99.45
# 7           render               99.80
# 8       SpeedIndex               99.93
# 9          docTime               99.97
# 10  ttfb_first_req              100.00

# %% [markdown]
# > ### Many of the Feature explain most of the variance in the 'loadTime' which is very expected but we here show that by statistical analysis

# %% [markdown]
# Thanks, I enjoyed working on this task. I tried my best to not use any domain knowledge and use math/statistics to land on the conclusions.
#
# -Ibrahim
